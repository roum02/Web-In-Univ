# %% [markdown]
# # **중간고사**

# %% [markdown]
# # **파이썬과데이터분석 중간고사 실습**
#
# 수학 계산기 프로그램을 작성한다. [50점]
# * 수업에서 배운 내용을 기반을 문제를 해결한다.
# * 프로그램 이해를 높이기 위해 주석을 적어야 한다.
#
# -------------------------------------------------------------------------------

# %% [markdown]
# **수학 계산기 프로그램 구조**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **classifyInt 함수 [배점 15점]**
#  - 입력 받은 정수들을 양의 정수와 음의 정수로 분리하는 함수
#  - parameter 이름: strNum
#   - **메인 프로그램**에서 사용자로 부터 입력 받은 **문자열**
#   - 단, 문자열은 음수와 양수로 구성되어 있고 0은 포함하지 않는다고 가정
#   - 예) -1, 1, 3, -2, 2
#  - return 값
#   - 앞부분은 음의 정수 뒷부분은 양의 정수로 이루어진 **리스트**
#   - 예) [-1, -2, 1, 3, 2]

# %%
#classifyInt 함수 구현

# %% [markdown]
# **reverseMT 함수 [배점 10점]:**
#   - 구구단을 역순으로 출력하는 함수
#   - parameter(매개변수): 없음
#   - return 값: 없음
#   - 음수 값이 입력되었을 경우 양수를 입력할 때까지 다시 입력 받는다.( 단, 정수를 입력한다고 가정)
#   - 올바른 입력값 확인하고 범위에 맞는 값을 입력할 때까지 반복
#
#
# > < 실행 결과 >
#
# > ```
# 출력을 시작할 단 입력:10
# 입력한 단수의 값이 잘못되었습니다.
# 다시 입력해 주세요 (입력할 값의 범위: 2~9)
# 출력을 시작할 단 입력:7
#  -  7단 -  -  6단 -  -  5단 -  -  4단 -  -  3단 -  -  2단 -
#  7X  9= 63 6X  9= 54 5X  9= 45 4X  9= 36 3X  9= 27 2X  9= 18
#  7X  8= 56 6X  8= 48 5X  8= 40 4X  8= 32 3X  8= 24 2X  8= 16
#  7X  7= 49 6X  7= 42 5X  7= 35 4X  7= 28 3X  7= 21 2X  7= 14
#  7X  6= 42 6X  6= 36 5X  6= 30 4X  6= 24 3X  6= 18 2X  6= 12
#  7X  5= 35 6X  5= 30 5X  5= 25 4X  5= 20 3X  5= 15 2X  5= 10
#  7X  4= 28 6X  4= 24 5X  4= 20 4X  4= 16 3X  4= 12 2X  4=  8
#  7X  3= 21 6X  3= 18 5X  3= 15 4X  3= 12 3X  3=  9 2X  3=  6
#  7X  2= 14 6X  2= 12 5X  2= 10 4X  2=  8 3X  2=  6 2X  2=  4
#  7X  1=  7 6X  1=  6 5X  1=  5 4X  1=  4 3X  1=  3 2X  1=  2
# ```
#
#
#
#
# < 부분 점수 없음 >
#   - 함수 호출을 통해 실행이 이루어지지 않을 경우 감점(-5)

# %%
# reverseMT 함수 구현

# %% [markdown]
# **메인 함수: 함수를 호출하는 부분**
#
# 조건 1) 메뉴는 다음과 같다. (각 번호는 메뉴 선택을 위해 사용자가 입력할 번호이다.)
# -  (1) 사용자가 입력한 숫자의 단부터 구구단을 역순으로 출력하기(reverseMT 함수 호출)
# -  (2) 입력받은 정수를 양의 정수와 음의 정수를 분리하기(classifyInt 함수 호출)
#   - 분리할 정수들을 입력받는다 (단, 양수와 음수 값만 입력했다고 가정한다.)
#
# 조건 2) 프로그램은 반복해서 실행되며 사용자가 -1을 입력하면 프로그램을 종료한다.

# %%
print("*****  수학 계산기 프로그램 시작  *****")








print("*****  수학 계산기 프로그램 종료  *****")
# Out:
# *****  수학 계산기 프로그램 시작  *****
# 수학 계산기 메뉴는 다음과 같습니다....
# (1) 사용자가 입력한 숫자의 단부터 구구단을 역순으로 출력하기
# (2) 입력받은 정수를 양의 정수와 음의 정수를 분리하기
# (-1) 프로그램 종료
# <입력 예>
# --------------------------------------------------------------------
# 수학 계산기 메뉴를 선택하세요....1
# 출력을 시작할 단 입력:6
#  -  6단 -  -  5단 -  -  4단 -  -  3단 -  -  2단 -
#  6X  9= 54 5X  9= 45 4X  9= 36 3X  9= 27 2X  9= 18
#  6X  8= 48 5X  8= 40 4X  8= 32 3X  8= 24 2X  8= 16
#  6X  7= 42 5X  7= 35 4X  7= 28 3X  7= 21 2X  7= 14
#  6X  6= 36 5X  6= 30 4X  6= 24 3X  6= 18 2X  6= 12
#  6X  5= 30 5X  5= 25 4X  5= 20 3X  5= 15 2X  5= 10
#  6X  4= 24 5X  4= 20 4X  4= 16 3X  4= 12 2X  4=  8
#  6X  3= 18 5X  3= 15 4X  3= 12 3X  3=  9 2X  3=  6
#  6X  2= 12 5X  2= 10 4X  2=  8 3X  2=  6 2X  2=  4
#  6X  1=  6 5X  1=  5 4X  1=  4 3X  1=  3 2X  1=  2
# --------------------------------------------------------------------
# 수학 계산기 메뉴는 다음과 같습니다....
# (1) 사용자가 입력한 숫자의 단부터 구구단을 역순으로 출력하기
# (2) 입력받은 정수를 양의 정수와 음의 정수를 분리하기
# (-1) 프로그램 종료
# <입력 예>
# ...
